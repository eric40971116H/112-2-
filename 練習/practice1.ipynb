# %%
import pandas as pd

df = pd.read_csv('222.csv')

df.head()
# Out:
#        娛樂稅稅源 申報家(件)數 查定家(件)數      申報營業總額 查定營業總額  本月份申報報繳稅額 本月份查定報繳稅額  \
# 0       合　　計     457     NaN  46,702,458    NaN  1,739,151       NaN
# 1    自動申報-總計      35     NaN  29,135,403    NaN    839,269       NaN
# 2    查定課徵-總計     418     NaN  17,170,605    NaN    897,912       NaN
# 3    臨時公演-總計       4     NaN     396,450    NaN      1,970       NaN
# 4  違章補徵稅款-總計     NaN     NaN         NaN    NaN        NaN       NaN
#
#     申報報繳稅額累計數 查定報繳稅額累計數  本月份申報實徵稅額 本月份查定實徵稅額   申報實徵稅額累計數 查定實徵稅額累計數  \
# 0  17,317,165       NaN  1,615,980       NaN  17,245,768       NaN
# 1   8,081,079       NaN    796,898       NaN   8,036,064       NaN
# 2   9,095,556       NaN    817,147       NaN   9,067,581       NaN
# 3     140,530       NaN     1,935        NaN     142,123       NaN
# 4         NaN       NaN        NaN       NaN         NaN       NaN
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
len(df)
# Out:
# 47

# %%
df
# Out:
#                                  娛樂稅稅源 申報家(件)數 查定家(件)數        申報營業總額  \
# 0                                 合　　計     457     NaN    46,702,458
# 1                              自動申報-總計      35     NaN    29,135,403
# 2                              查定課徵-總計     418     NaN    17,170,605
# 3                              臨時公演-總計       4     NaN       396,450
# 4                            違章補徵稅款-總計     NaN     NaN           NaN
# 5                            電影0-小　　　計      2       -     2,451,841
# 6                         電影0-本國片繁榮地區A      -       -             -
# 7                         電影0-本國片偏僻地區B      -       -             -
# 8                           電影0-本國片郊區C      -       -             -
# 9                         電影0-外國片繁榮地區D      -       -             -
# 10                        電影0-外國片偏僻地區E      -       -             -
# 11                          電影0-外國片郊區F      -       -             -
# 12                          電影0-國洋片混片G      2       -     2,451,841
# ...

# %%
temp = df[['娛樂稅稅源','申報家(件)數','申報營業總額']]
temp
# Out:
#                                  娛樂稅稅源 申報家(件)數        申報營業總額
# 0                                 合　　計     457    46,702,458
# 1                              自動申報-總計      35    29,135,403
# 2                              查定課徵-總計     418    17,170,605
# 3                              臨時公演-總計       4       396,450
# 4                            違章補徵稅款-總計     NaN           NaN
# 5                            電影0-小　　　計      2     2,451,841
# 6                         電影0-本國片繁榮地區A      -             -
# 7                         電影0-本國片偏僻地區B      -             -
# 8                           電影0-本國片郊區C      -             -
# 9                         電影0-外國片繁榮地區D      -             -
# 10                        電影0-外國片偏僻地區E      -             -
# 11                          電影0-外國片郊區F      -             -
# 12                          電影0-國洋片混片G      2     2,451,841
# 13                             電影0-其他H      -             -
# 14                                 歌廳1      -             -
# ...

# %%
Type = temp.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額'].sum().reset_index()
# Out:
# C:\Users\Eric\AppData\Local\Temp\ipykernel_21264\2593871068.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Type = temp.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額'].sum().reset_index()

# %%
Type = temp.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額']
Type
# Out:
# C:\Users\Eric\AppData\Local\Temp\ipykernel_21264\3383526474.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Type = temp.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額']

# %%
Type['month'] = ('11月')
Type
# Out:
#    申報家(件)數                                              娛樂稅稅源  \
# 0       -   電影0-本國片繁榮地區A電影0-本國片偏僻地區B電影0-本國片郊區C電影0-外國片繁榮地區D...
# 1       1   高爾夫球場4-小　計高爾夫球場4-球　場A其他9-具娛樂性之選物販賣機C其他9-機動遊藝樂園...
# 2       2                                 電影0-小　　　計電影0-國洋片混片G
# 3      24                                             其他9-其他G
# 4      27                                              其他9-小計
# 5       4             臨時公演-小　　　計臨時公演-說書、戲劇、音樂演奏及非職業性歌唱、舞蹈等表演B
# 6       5                   視聽視唱業8-小　　　計視聽視唱業8-KTV(卡拉ok)非投幣式B
# 7       35                                            自動申報-總計
# 8        4                                            臨時公演-總計
# 9      418                                            查定課徵-總計
# 10     457                                               合　　計
#
#                                                申報營業總額 month
# 0    -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  ...   11月
# 1    3,845,590  3,845,590  46,547  11,655,780  277...   11月
# ...

# %%
import pandas as pd

df1 = pd.read_csv('333.csv')

df1.head()
# Out:
#        娛樂稅稅源 申報家(件)數 查定家(件)數      申報營業總額 查定營業總額  本月份申報報繳稅額 本月份查定報繳稅額  \
# 0       合　　計     464     NaN  54,840,164    NaN  1,760,385       NaN
# 1    自動申報-總計      37     NaN  31,591,567    NaN    861,545       NaN
# 2    查定課徵-總計     419     NaN  17,033,005    NaN    891,732       NaN
# 3    臨時公演-總計       8     NaN   6,215,592    NaN      7,108       NaN
# 4  違章補徵稅款-總計     NaN     NaN         NaN    NaN        NaN       NaN
#
#     申報報繳稅額累計數 查定報繳稅額累計數  本月份申報實徵稅額 本月份查定實徵稅額   申報實徵稅額累計數 查定實徵稅額累計數  \
# 0  19,077,550       NaN  1,880,420       NaN  19,126,188       NaN
# 1   8,942,624       NaN    854,355       NaN   8,890,419       NaN
# 2   9,987,288       NaN  1,024,485       NaN  10,092,066       NaN
# 3     147,638       NaN     1,580        NaN     143,703       NaN
# 4         NaN       NaN        NaN       NaN         NaN       NaN
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
temp1 = df1[['娛樂稅稅源','申報家(件)數','申報營業總額']]
temp1
# Out:
#                                  娛樂稅稅源 申報家(件)數        申報營業總額
# 0                                 合　　計     464    54,840,164
# 1                              自動申報-總計      37    31,591,567
# 2                              查定課徵-總計     419    17,033,005
# 3                              臨時公演-總計       8     6,215,592
# 4                            違章補徵稅款-總計     NaN           NaN
# 5                            電影0-小　　　計      2     2,079,751
# 6                         電影0-本國片繁榮地區A      -             -
# 7                         電影0-本國片偏僻地區B      -             -
# 8                           電影0-本國片郊區C      -             -
# 9                         電影0-外國片繁榮地區D      -             -
# 10                        電影0-外國片偏僻地區E      -             -
# 11                          電影0-外國片郊區F      -             -
# 12                          電影0-國洋片混片G      2     2,079,751
# 13                             電影0-其他H      -             -
# 14                                 歌廳1      -             -
# ...

# %%
type1 = temp1.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額'].sum().reset_index()
# Out:
# C:\Users\Eric\AppData\Local\Temp\ipykernel_7280\1917186339.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   type1 = temp1.groupby(['申報家(件)數'])['娛樂稅稅源','申報營業總額'].sum().reset_index()

# %%
type1['month'] = ('10月')
type1
# Out:
#    申報家(件)數                                              娛樂稅稅源  \
# 0       -   電影0-本國片繁榮地區A電影0-本國片偏僻地區B電影0-本國片郊區C電影0-外國片繁榮地區D...
# 1       1   高爾夫球場4-小　計高爾夫球場4-球　場A其他9-具娛樂性之選物販賣機C其他9-機動遊藝樂園...
# 2       2                                 電影0-小　　　計電影0-國洋片混片G
# 3      26                                             其他9-其他G
# 4      29                                              其他9-小計
# 5       3                                        臨時公演-各種競技比賽C
# 6       5   視聽視唱業8-小　　　計視聽視唱業8-KTV(卡拉ok)非投幣式B臨時公演-說書、戲劇、音樂...
# 7       8                                          臨時公演-小　　　計
# 8       37                                            自動申報-總計
# 9      419                                            查定課徵-總計
# 10     464                                               合　　計
# 11       8                                            臨時公演-總計
#
#                                                申報營業總額 month
# 0    -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  ...   10月
# ...

# %%
frames = [ Type , type1]

result = pd.concat(frames)
result
# Out:
#    申報家(件)數                                              娛樂稅稅源  \
# 0       -   電影0-本國片繁榮地區A電影0-本國片偏僻地區B電影0-本國片郊區C電影0-外國片繁榮地區D...
# 1       1   高爾夫球場4-小　計高爾夫球場4-球　場A其他9-具娛樂性之選物販賣機C其他9-機動遊藝樂園...
# 2       2                                 電影0-小　　　計電影0-國洋片混片G
# 3      24                                             其他9-其他G
# 4      27                                              其他9-小計
# 5       4             臨時公演-小　　　計臨時公演-說書、戲劇、音樂演奏及非職業性歌唱、舞蹈等表演B
# 6       5                   視聽視唱業8-小　　　計視聽視唱業8-KTV(卡拉ok)非投幣式B
# 7       35                                            自動申報-總計
# 8        4                                            臨時公演-總計
# 9      418                                            查定課徵-總計
# 10     457                                               合　　計
# 0       -   電影0-本國片繁榮地區A電影0-本國片偏僻地區B電影0-本國片郊區C電影0-外國片繁榮地區D...
# 1       1   高爾夫球場4-小　計高爾夫球場4-球　場A其他9-具娛樂性之選物販賣機C其他9-機動遊藝樂園...
# 2       2                                 電影0-小　　　計電影0-國洋片混片G
# ...
